# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## Carga de los datos

# %%
class EDFData():
    def __init__(self, path):
        self.path = path
        # self.data = mne.io.read_raw_edf(path)
        # self.events, self.events_id = mne.events_from_annotations(self.data, regexp='Sleep stage')
        self.epochs = self.get_epochs(path)
        self.id_to_class_dict = {value:key for key, value in self.epochs.event_id.items()}

    def __getitem__(self, idx):
        return self.epochs[idx].load_data()._data, self.epochs[idx].events[0][-1]
    # def __getitem__(self, idx):
    #     return self.epochs[idx]._data, self.epochs[idx].events[0][-1]

    def get_epochs(self, path):
        data = mne.io.read_raw_edf(path)
        events, events_id = mne.events_from_annotations(data, regexp='Sleep stage')

        tmax = 30. - 1. / data.info['sfreq']  # tmax is included
        epochs = mne.Epochs(raw=data, 
                            events=events,
                            event_id=events_id,
                            tmin=0., 
                            tmax=tmax, 
                            baseline=None, 
                            event_repeated='merge')
        # epochs.load_data()
        return epochs

# %%
dataset = EDFData("../Data/PSG1_0001.edf")
# Out:
# Extracting EDF parameters from e:\Python\TFM\SSD_IA3\Data\PSG1_0001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage N1', 'Sleep stage N2', 'Sleep stage N3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 862 matching events found
# No baseline correction applied
# 0 projection items activated
# <ipython-input-2-5d1e224fed92>:15: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   data = mne.io.read_raw_edf(path)
# <ipython-input-2-5d1e224fed92>:15: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   data = mne.io.read_raw_edf(path)

# %%
# %%time
for a, b in dataset:
    # print(a.shape)
# Out:
# )
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (1, 50, 15360)
# Loading data for 1 events and 15360 original time points ...
# 1 bad epochs dropped
# (0, 50, 15360)
# Wall time: 20 s

# %%
dataset[0]
# Out:
# Loading data for 1 events and 15360 original time points ...
# 0 bad epochs dropped
# (array([[[-4.17761501e-04, -4.17761501e-04, -4.14795148e-04, ...,
#           -9.47585260e-05, -1.02668803e-04, -9.67360952e-05],
#          [-3.59423209e-04, -3.52172122e-04, -3.56127260e-04, ...,
#           -1.71554131e-04, -1.80123598e-04, -1.75509270e-04],
#          [-3.22508583e-04, -3.16575875e-04, -3.10313573e-04, ...,
#           -1.69741360e-05, -1.07118334e-05, -8.23987182e-07],
#          ...,
#          [ 2.88395514e-03,  2.88395514e-03,  2.05996796e-03, ...,
#            2.22476539e-03,  2.22476539e-03,  2.22476539e-03],
#          [ 9.44012299e+01,  9.44012299e+01,  9.44012299e+01, ...,
#            9.31992431e+01,  9.31992431e+01,  9.31992431e+01],
#          [ 6.60000000e+01,  6.60000000e+01,  6.60000000e+01, ...,
#            6.89971618e+01,  6.89971618e+01,  6.89971618e+01]]]),
#  5)

# %%
dataset.id_to_class_dict
# Out:
# {1: 'Sleep stage N1',
#  2: 'Sleep stage N2',
#  3: 'Sleep stage N3',
#  4: 'Sleep stage R',
#  5: 'Sleep stage W'}
